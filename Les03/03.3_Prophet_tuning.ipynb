# %% [markdown]
# #### Forecasting Timeseries Data Using Facebook FbProphet
#
# Steps Required With Prophet
# 1. Introduction
# 2. Data Preprocessing With Time Seires
# 3. Model Fitting
# 4. Obtaining The Forecasts
# 5. Plotting The Forecasts
# 6. Cross Validation
# 7. Computing Performance Metrics
# 8. Visualize the Performance Metrics

# %%
import pandas as pd
import matplotlib.pyplot as plt

from prophet import Prophet
from prophet.diagnostics import cross_validation,performance_metrics
from prophet.plot import plot_cross_validation_metric

# %matplotlib inline

# %%
# !wget https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/monthly-milk-production-pounds.csv
# Out:
# --2022-12-12 19:45:51--  https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/monthly-milk-production-pounds.csv
# Resolving frenzy86.s3.eu-west-2.amazonaws.com (frenzy86.s3.eu-west-2.amazonaws.com)... 3.5.245.108
# Connecting to frenzy86.s3.eu-west-2.amazonaws.com (frenzy86.s3.eu-west-2.amazonaws.com)|3.5.245.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2478 (2.4K) [text/csv]
# Saving to: ‘monthly-milk-production-pounds.csv’
#
# monthly-milk-produc 100%[===================>]   2.42K  --.-KB/s    in 0s
#
# 2022-12-12 19:45:53 (93.6 MB/s) - ‘monthly-milk-production-pounds.csv’ saved [2478/2478]

# %%
df=pd.read_csv('monthly-milk-production-pounds.csv')
df
# Out:
#                                                  Month  \
# 0                                              1962-01
# 1                                              1962-02
# 2                                              1962-03
# 3                                              1962-04
# 4                                              1962-05
# ..                                                 ...
# 164                                            1975-09
# 165                                            1975-10
# 166                                            1975-11
# 167                                            1975-12
# 168  Monthly milk production: pounds per cow. Jan 6...
#
#      Monthly milk production: pounds per cow. Jan 62 ? Dec 75
# 0                                                589.0
# 1                                                561.0
# 2                                                640.0
# 3                                                656.0
# 4                                                727.0
# ..                                                 ...
# 164                                              817.0
# 165                                              827.0
# 166                                              797.0
# 167                                              843.0
# 168                                                NaN
#
# [169 rows x 2 columns]

# %%
df.drop(168,axis=0,inplace=True)

# %%
df.tail()
# Out:
#        Month  Monthly milk production: pounds per cow. Jan 62 ? Dec 75
# 163  1975-08                                              858.0
# 164  1975-09                                              817.0
# 165  1975-10                                              827.0
# 166  1975-11                                              797.0
# 167  1975-12                                              843.0

# %%
df.columns=["ds","y"]

# %%
df.plot(figsize=(18,10))

# %%
df.head(14)
# Out:
#            ds      y
# 0  1962-01-01  589.0
# 1  1962-02-01  561.0
# 2  1962-03-01  640.0
# 3  1962-04-01  656.0
# 4  1962-05-01  727.0
# 5  1962-06-01  697.0
# 6  1962-07-01  640.0
# 7  1962-08-01  599.0
# 8  1962-09-01  568.0
# 9  1962-10-01  577.0
# 10 1962-11-01  553.0
# 11 1962-12-01  582.0
# 12 1963-01-01  600.0
# 13 1963-02-01  566.0

# %%
df['ds']=pd.to_datetime(df['ds'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 168 entries, 0 to 167
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      168 non-null    datetime64[ns]
#  1   y       168 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 3.9 KB

# %%
df['y'].plot(figsize=(18,10));

# %%
dir(Prophet)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_load_stan_backend',
#  '_logistic_uncertainty',
#  '_make_historical_mat_time',
#  '_make_trend_shift_matrix',
#  '_sample_uncertainty',
#  'add_country_holidays',
#  'add_group_component',
#  'add_regressor',
#  'add_seasonality',
#  'construct_holiday_dataframe',
#  'fit',
#  'flat_growth_init',
#  'flat_trend',
#  'fourier_series',
#  'initialize_scales',
#  'linear_growth_init',
#  'logistic_growth_init',
#  'make_all_seasonality_features',
#  'make_future_dataframe',
#  'make_holiday_features',
#  'make_seasonality_features',
#  'parse_seasonality_args',
#  'percentile',
#  'piecewise_linear',
#  'piecewise_logistic',
#  'plot',
#  'plot_components',
#  'predict',
#  'predict_seasonal_components',
#  'predict_trend',
#  'predict_uncertainty',
#  'predictive_samples',
#  'regressor_column_matrix',
#  'sample_model',
#  'sample_model_vectorized',
#  'sample_posterior_predictive',
#  'sample_predictive_trend',
#  'sample_predictive_trend_vectorized',
#  'set_auto_seasonalities',
#  'set_changepoints',
#  'setup_dataframe',
#  'validate_column_name',
#  'validate_inputs']

# %%
### intiialize the Model
m=Prophet()
model = m.fit(df)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/b0hx9us1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/wx7xhcxf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=55516', 'data', 'file=/tmp/tmp7pouhm3t/b0hx9us1.json', 'init=/tmp/tmp7pouhm3t/wx7xhcxf.json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_modelphm91vw0/prophet_model-20221212194841.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:48:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:48:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
model

# %%
model.seasonalities
# Out:
# OrderedDict([('yearly',
#               {'period': 365.25,
#                'fourier_order': 10,
#                'prior_scale': 10.0,
#                'mode': 'additive',
#                'condition_name': None})])

# %%
model.component_modes
# Out:
# {'additive': ['yearly',
#   'additive_terms',
#   'extra_regressors_additive',
#   'holidays'],
#  'multiplicative': ['multiplicative_terms', 'extra_regressors_multiplicative']}

# %%
#### Create future dates of 365 days
#
future = model.make_future_dataframe(periods=24, freq='MS')
future
# Out:
#             ds
# 0   1962-01-01
# 1   1962-02-01
# 2   1962-03-01
# 3   1962-04-01
# 4   1962-05-01
# ..         ...
# 187 1977-08-01
# 188 1977-09-01
# 189 1977-10-01
# 190 1977-11-01
# 191 1977-12-01
#
# [192 rows x 1 columns]

# %%
df.tail()
# Out:
#             ds      y
# 163 1975-08-01  858.0
# 164 1975-09-01  817.0
# 165 1975-10-01  827.0
# 166 1975-11-01  797.0
# 167 1975-12-01  843.0

# %%
168+24
# Out:
# 192

# %%
future
# Out:
#             ds
# 0   1962-01-01
# 1   1962-02-01
# 2   1962-03-01
# 3   1962-04-01
# 4   1962-05-01
# ..         ...
# 187 1977-08-01
# 188 1977-09-01
# 189 1977-10-01
# 190 1977-11-01
# 191 1977-12-01
#
# [192 rows x 1 columns]

# %%
### Prediction
forecast = model.predict(future)

# %%
forecast.head()
# Out:
#           ds       trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0 1962-01-01  606.699621  575.972641  596.906038   606.699621   606.699621
# 1 1962-02-01  608.429151  535.722606  555.165258   608.429151   608.429151
# 2 1962-03-01  609.991307  631.973932  651.445968   609.991307   609.991307
# 3 1962-04-01  611.720837  648.312249  668.058912   611.720837   611.720837
# 4 1962-05-01  613.394576  711.378615  731.300969   613.394576   613.394576
#
#    additive_terms  additive_terms_lower  additive_terms_upper      yearly  \
# 0      -20.112380            -20.112380            -20.112380  -20.112380
# 1      -62.538270            -62.538270            -62.538270  -62.538270
# 2       31.410964             31.410964             31.410964   31.410964
# 3       46.736560             46.736560             46.736560   46.736560
# 4      108.067398            108.067398            108.067398  108.067398
#
#    yearly_lower  yearly_upper  multiplicative_terms  \
# 0    -20.112380    -20.112380                   0.0
# 1    -62.538270    -62.538270                   0.0
# 2     31.410964     31.410964                   0.0
# 3     46.736560     46.736560                   0.0
# 4    108.067398    108.067398                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper        yhat
# 0                         0.0                         0.0  586.587241
# 1                         0.0                         0.0  545.890881
# 2                         0.0                         0.0  641.402271
# 3                         0.0                         0.0  658.457397
# 4                         0.0                         0.0  721.461974

# %%
forecast[['ds','yhat','yhat_lower','yhat_upper']].tail()
# Out:
#             ds        yhat  yhat_lower  yhat_upper
# 187 1977-08-01  867.790184  852.232413  881.698885
# 188 1977-09-01  826.105396  810.780977  840.529443
# 189 1977-10-01  830.129331  813.797697  846.860469
# 190 1977-11-01  800.346872  782.207304  816.648783
# 191 1977-12-01  838.162733  819.551640  855.632055

# %%
forecast[['ds','yhat','yhat_lower','yhat_upper']].head()
# Out:
#           ds        yhat  yhat_lower  yhat_upper
# 0 1962-01-01  586.587241  575.972641  596.906038
# 1 1962-02-01  545.890881  535.722606  555.165258
# 2 1962-03-01  641.402271  631.973932  651.445968
# 3 1962-04-01  658.457397  648.312249  668.058912
# 4 1962-05-01  721.461974  711.378615  731.300969

# %% [markdown]
# #### Plotting the Forecasts
#
# Prophet has an inbuilt feature that enables us to plot the forecasts we just generated. This is achieved using model.plot() and passing in our forecasts as the argument. The blue line in the graph represents the predicted values while the black dots represents the data in our dataset.

# %%
#### plot the predicted projection
model.plot(forecast);

# %%
##### Visualize Each Components[Trends,Weekly]
model.plot_components(forecast);

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error,mean_squared_error

df_merge = pd.merge(df, forecast[['ds','yhat_lower','yhat_upper','yhat']],on='ds')
df_merge = df_merge[['ds','yhat_lower','yhat_upper','yhat','y']]
df_merge.tail()
# Out:
#             ds  yhat_lower  yhat_upper        yhat      y
# 163 1975-08-01  845.380906  865.409511  855.394251  858.0
# 164 1975-09-01  803.236461  823.248999  812.902264  817.0
# 165 1975-10-01  806.726630  827.538871  817.365186  827.0
# 166 1975-11-01  776.696831  796.259716  786.145581  797.0
# 167 1975-12-01  813.202338  832.725574  822.969184  843.0

# %%
# calculate MAE between observed and predicted values 
y_true = df_merge['y'].values
y_pred = df_merge['yhat'].values

mae_01 = mean_absolute_error(y_true, y_pred)
print('MAE: %.3f' % mae_01)

mse_01 = mean_squared_error(y_true, y_pred)
print('MSE: %.3f' % mse_01)

mape_01 = mean_absolute_percentage_error(y_true, y_pred)
print(f'MAPE: %.3f' % mape_01)
# Out:
# MAE: 5.896
# MSE: 59.419
# MAPE: 0.008

# %% [markdown]
# #### Cross Validation
#
# Next let’s measure the forecast error using the historical data. We’ll do this by comparing the predicted values with the actual values. In order to perform this operation we select cut of points in the history of the data and fit the model with data upto that cut off point. Afterwards we compare the actual values to the predicted values. The cross_validation method allows us to do this in Prophet. This method take the following parameters as explained below:
#
# 1. horizon the forecast horizon
# 2. initial the size of the initial training period
# 3. period the spacing between cutoff dates

# %%
df.shape
# Out:
# (168, 2)

# %% [markdown]
# cross_validation(m, initial='730 days', period='180 days', horizon = '365 days')
#
# - shift from 180 days
#
# Here we do cross-validation to assess prediction performance on a horizon of 365 days, starting with 730 days of training data in the first cutoff and then making predictions every 180 days. On this 8 year time series, this corresponds to 11 total forecasts.

# %% [markdown]
# #### Cross Validation
# https://facebook.github.io/prophet/docs/diagnostics.html
#
# <img src="https://facebook.github.io/prophet/static/diagnostics_files/diagnostics_4_0.png" width="800">

# %%
from prophet.diagnostics import cross_validation

df_cv = cross_validation(model,
                        horizon="365 days",
                        period='180 days',#cutoff -->shifting cross validation
                        initial='1095 days',
                        #parallel="dask"#need to install dask
                        )
# Out:
# INFO:prophet:Making 21 forecasts with cutoffs between 1965-01-22 00:00:00 and 1974-12-01 00:00:00
#   0%|          | 0/21 [00:00<?, ?it/s]
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/_96kw_js.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/0fx_xhve.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=73571', 'data', 'file=/tmp/tmp7pouhm3t/_96kw_js.json', 'init=/tmp/tmp7pouhm3t/0fx_xhve.json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_modeleclxz6mw/prophet_model-20221212195801.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:58:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:58:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/d4jotq0n.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/iqk3wul6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=57801', 'data', 'file=/tmp/tmp7pouhm3t/d4jotq0n.json', 'init=/tmp/tmp7pouhm3t/iqk3wul6.json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_model74l_e58p/prophet_model-20221212195826.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:58:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:58:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/xocrfxb2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/hukilczg.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99326', 'data', 'file=/tmp/tmp7pouhm3t/xocrfxb2.json', 'init=/tmp/tmp7pouhm3t/hukilczg.json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_modely4i2wj0v/prophet_model-20221212195827.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:58:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:58:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/ayvgo6ll.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/ntlkpkxj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31901', 'data', 'file=/tmp/tmp7pouhm3t/ayvgo6ll.json', 'init=/tmp/tmp7pouhm3t/ntlkpkxj.json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_modelh9zi56xo/prophet_model-20221212195828.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:58:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:58:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/uilklw26.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/xu9v6psn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=3711', 'data', 'file=/tmp/tmp7pouhm3t/uilklw26.json', 'init=/tmp/tmp7pouhm3t/xu9v6psn.json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_modelg23bfdsl/prophet_model-20221212195829.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:58:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:58:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/8gsb269g.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/5u5t1311.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=
json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_modelujelb8nd/prophet_model-20221212195841.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:58:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:58:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/v92x4clr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/kuykndnc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=34744', 'data', 'file=/tmp/tmp7pouhm3t/v92x4clr.json', 'init=/tmp/tmp7pouhm3t/kuykndnc.json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_modelth_lcgiz/prophet_model-20221212195842.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:58:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:58:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
df_cv
# Out:
#             ds        yhat  yhat_lower  yhat_upper      y     cutoff
# 0   1965-02-01  618.160397  616.079641  620.611659  622.0 1965-01-22
# 1   1965-03-01  697.902700  691.640324  705.560105  709.0 1965-01-22
# 2   1965-04-01  710.287039  697.338704  725.263690  722.0 1965-01-22
# 3   1965-05-01  774.521395  753.789855  798.967243  782.0 1965-01-22
# 4   1965-06-01  742.419506  712.926506  776.353847  756.0 1965-01-22
# ..         ...         ...         ...         ...    ...        ...
# 247 1975-08-01  850.222620  840.219112  859.917717  858.0 1974-12-01
# 248 1975-09-01  807.780168  798.042482  818.360909  817.0 1974-12-01
# 249 1975-10-01  811.219324  800.748515  821.351192  827.0 1974-12-01
# 250 1975-11-01  779.237213  769.211538  789.850569  797.0 1974-12-01
# 251 1975-12-01  813.749404  802.934423  824.795172  843.0 1974-12-01
#
# [252 rows x 6 columns]

# %% [markdown]
# #### Obtaining the Performance Metrics
#
# We use the performance_metrics utility to compute the Mean Squared Error(MSE), Root Mean Squared Error(RMSE),Mean Absolute Error(MAE), Mean Absolute Percentage Error(MAPE) and the coverage of the the yhat_lower and yhat_upper estimates.

# %%
from prophet.diagnostics import performance_metrics
df_performance = performance_metrics(df_cv)
df_performance.head()
# Out:
#   horizon         mse       rmse        mae      mape     mdape     smape  \
# 0 38 days  257.316317  16.041082  12.569412  0.016151  0.014480  0.016144
# 1 41 days  255.394155  15.981056  12.491907  0.016088  0.014480  0.016080
# 2 42 days  270.529526  16.447782  12.959755  0.016738  0.014534  0.016739
# 3 43 days  272.202257  16.498553  13.172641  0.017076  0.014534  0.017080
# 4 46 days  258.259695  16.070460  12.889844  0.016699  0.014534  0.016687
#
#    coverage
# 0      0.32
# 1      0.32
# 2      0.32
# 3      0.32
# 4      0.32

# %%
from prophet.plot import plot_cross_validation_metric
fig=plot_cross_validation_metric(df_cv,metric='rmse')
# Out:
# /usr/local/lib/python3.8/dist-packages/prophet/plot.py:544: FutureWarning: casting timedelta64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.
#   x_plt = df_none['horizon'].astype('timedelta64[ns]').astype(np.int64) / float(dt_conversions[i])
# /usr/local/lib/python3.8/dist-packages/prophet/plot.py:545: FutureWarning: casting timedelta64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.
#   x_plt_h = df_h['horizon'].astype('timedelta64[ns]').astype(np.int64) / float(dt_conversions[i])

# %%
fig=plot_cross_validation_metric(df_cv,metric='mape')
# Out:
# /usr/local/lib/python3.8/dist-packages/prophet/plot.py:544: FutureWarning: casting timedelta64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.
#   x_plt = df_none['horizon'].astype('timedelta64[ns]').astype(np.int64) / float(dt_conversions[i])
# /usr/local/lib/python3.8/dist-packages/prophet/plot.py:545: FutureWarning: casting timedelta64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.
#   x_plt_h = df_h['horizon'].astype('timedelta64[ns]').astype(np.int64) / float(dt_conversions[i])

# %%
df_performance.mean()
# Out:
# horizon     201 days 23:44:25.945945946
# mse                            482.0103
# rmse                          21.514545
# mae                           16.704752
# mape                           0.021049
# mdape                          0.016359
# smape                          0.020965
# coverage                       0.370054
# dtype: object

# %% [markdown]
# I struggled with this for a while as well. But here is how it works. The initial model will be trained on the first 1,825 days of data. It will forecast the next 60 days of data (because horizon is set to 60). The model will then train on the initial period + the period (1,825 + 30 days in this case) and forecast the next 60 days. It will continued like this, adding another 30 days to the training data and then forecasting for the next 60 until there is no longer enough data to do this.
#
# In summary, period is how much data to add to the training data set in every iteration of cross-validation, and horizon is how far out it will forecast.

# %% [markdown]
# ## Hyperparameter tuning

# %% [markdown]
# Cross-validation can be used for tuning hyperparameters of the model, such as changepoint_prior_scale and seasonality_prior_scale. A Python example is given below, with a 4x4 grid of those two parameters, with parallelization over cutoffs. Here parameters are evaluated on RMSE averaged over a 365-day horizon, but different performance metrics may be appropriate for different problems.

# %%
# Python
import itertools
import numpy as np
import pandas as pd

#'changepoint_range': [0.6, 0.7, 0.75, 0.8, 0.9],
#'holidays_prior_scale':[1.0, 5.0, 10.0, 15.0],
#'yearly_seasonality':[5, 10, 15, 20],
#'weekly_seasonality':[5, 10, 15, 20],


param_grid = {  
    'changepoint_prior_scale': [0.001, 0.01, 0.1, 0.5],
    'seasonality_prior_scale': [0.01, 0.1, 1.0, 10.0],
}

# Generate all combinations of parameters
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]
rmses = []  # Store the RMSEs for each params here


# Use cross validation to evaluate all parameters
for params in all_params:
    model = Prophet(**params).fit(df)  # Fit model with given params
    df_cv = cross_validation(model, 
                             horizon="365 days",
                             period='180 days', #shift - moving windows
                             initial='1095 days', 
                             )
    
    df_p = performance_metrics(df_cv, rolling_window=1)
    rmses.append(df_p['rmse'].values[0])

# Find the best parameters
tuning_results = pd.DataFrame(all_params)
tuning_results['rmse'] = rmses
print(tuning_results)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/6a80mg4g.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/_vj1zmzn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=67847', 'data', 'file=/tmp/tmp7pouhm3t/6a80mg4g.json', 'init=/tmp/tmp7pouhm3t/_vj1zmzn.json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_model9dj0j3n5/prophet_model-20221212200408.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:04:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:04:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 20:04:08 - cmdstanpy - ERROR - Chain [1] error: error during processing Communication error on send
# ERROR:cmdstanpy:Chain [1] error: error during processing Communication error on send
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/_ahumiug.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/rhu9m389.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56193', 'data', 'file=/tmp/tmp7pouhm3t/_ahumiug.json', 'init=/tmp/tmp7pouhm3t/rhu9m389.json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_modelu3voctw0/prophet_model-20221212200408.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 20:04:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:04:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 21 forecasts with cutoffs between 1965-01-22 00:00:00 and 1974-12-01 00:00:00
#   0%|          | 0/21 [00:00<?, ?it/s]
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/qhmgyzmh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/1ofqx_ut.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=24141', 'data', 'file=/tmp/tmp7pouhm3t/qhmgyzmh.json', 'init=/tmp/tmp7pouhm3t/1ofqx_ut.json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_modelg9ywoqlz/prophet_model-20221212200408.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 20:04:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:04:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/vdjt9asn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/6d89gnpw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=73676', 'data', 'file=/tmp/tmp7pouhm3t/vdjt9asn.json', 'init=/tmp/tmp7pouhm3t/6d89gnpw.json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_modelj_g4zji8/prophet_model-20221212200409.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 20:04:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:04:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/ni0eh4bi.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/feg29xl3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=53425', 'data', 'file=/tmp/tmp7pouhm3t/ni0eh4bi.json', 'init=/tmp/tmp7pouhm3t/feg29xl3.json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_modelmslacp1i/prophet_model-20221212200410.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 20:04:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:04:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/pqihg7i7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/kg59iy6z.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=87408', 'data', 'file=/tmp/tmp7pouhm3t/pqihg7i7.json', 'init=/tmp/tmp7pouhm3t/kg59iy6z.json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_modelospcs8wy/prophet_model-20221212200411.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 20:04:11 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:04:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/e_b743cs.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/wkcq2u0j.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=22770', 'data', 'file=/tmp/tmp7pouhm3t/e_b743cs.json', 'init=/tmp/tmp7pouhm3t/wkcq2u0j.json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_modelxswuy47c/prophet_model-20221212200412.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 20:04:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:04:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/hlq50b35.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/j998t4vc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=84059', 'data', 'file=/tmp/tmp7pouhm3t/hlq50b35.json', 'init=/tmp/tmp7pouhm3t/j998t4vc.json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_modelqw7bvnng/prophet_model-20221212200412.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 20:04:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:04:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/2atyxla8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/wrxiitt4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30064', 'data', 'file=/tmp/tmp7pouhm3t/2atyxla8.json', 'init=/tmp/tmp7pouhm3t/wrxiitt4.json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_model12galy9e/prophet_model-20221212200413.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 20:04:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:04:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/malewotw.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/zamc5ryy.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=74113', 'data', 'file=/tmp/tmp7pouhm3t/malewotw.json', 'init=/tmp/tmp7pouhm3t/zamc5ryy.json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_modelyzj67ppw/prophet_model-20221212200414.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 20:04:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:04:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/g9pgs5i6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/x7d6w62j.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=42364', 'data', 'file=/tmp/tmp7pouhm3t/g9pgs5i6.json', 'init=/tmp/tmp7pouhm3t/x7d6w62j.json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_modelp9l676q7/prophet_model-20221212200415.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 20:04:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:04:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/9abka72g.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/zd0v31nn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=77373', 'data', 'file=/tmp/tmp7pouhm3t/9abka72g.json', 'init=/tmp/tmp7pouhm3t/zd0v31nn.json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_mod
json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72103', 'data', 'file=/tmp/tmp7pouhm3t/_u88m6iv.json', 'init=/tmp/tmp7pouhm3t/v4bcdtue.json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_modell3zp2hi1/prophet_model-20221212201211.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:12:11 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:12:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/6qnaf05a.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/_5d_ea7u.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=77523', 'data', 'file=/tmp/tmp7pouhm3t/6qnaf05a.json', 'init=/tmp/tmp7pouhm3t/_5d_ea7u.json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_modelfaa2kx_k/prophet_model-20221212201211.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:12:11 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:12:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/m3sbwytv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/kfr4s086.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=97691', 'data', 'file=/tmp/tmp7pouhm3t/m3sbwytv.json', 'init=/tmp/tmp7pouhm3t/kfr4s086.json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_modelth2zng57/prophet_model-20221212201212.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:12:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:12:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/w7gmih5p.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/s7mt9r5x.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=22971', 'data', 'file=/tmp/tmp7pouhm3t/w7gmih5p.json', 'init=/tmp/tmp7pouhm3t/s7mt9r5x.json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_modelx_yb3x7g/prophet_model-20221212201213.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:12:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:12:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/bv3js61z.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/13zg90pk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=83307', 'data', 'file=/tmp/tmp7pouhm3t/bv3js61z.json', 'init=/tmp/tmp7pouhm3t/13zg90pk.json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_model3wwvyzrb/prophet_model-20221212201213.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:12:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:12:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/s7qqpgf0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/h5qslg6u.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=9583', 'data', 'file=/tmp/tmp7pouhm3t/s7qqpgf0.json', 'init=/tmp/tmp7pouhm3t/h5qslg6u.json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_modellq5p4bxb/prophet_model-20221212201214.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:12:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:12:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/tnmldc4g.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/zf72pt7o.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=83341', 'data', 'file=/tmp/tmp7pouhm3t/tnmldc4g.json', 'init=/tmp/tmp7pouhm3t/zf72pt7o.json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_modelx3r7rpz2/prophet_model-20221212201215.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:12:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:12:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/iaeq4n7w.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/z7n_qtq0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=76076', 'data', 'file=/tmp/tmp7pouhm3t/iaeq4n7w.json', 'init=/tmp/tmp7pouhm3t/z7n_qtq0.json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_models26bqxqh/prophet_model-20221212201216.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:12:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:12:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#     changepoint_prior_scale  seasonality_prior_scale       rmse
# 0                     0.001                     0.01  21.033912
# 1                     0.001                     0.10  20.922118
# 2                     0.001                     1.00  20.912287
# 3                     0.001                    10.00  20.824813
# 4                     0.010                     0.01  21.380825
# 5                     0.010                     0.10  21.255852
# 6                     0.010                     1.00  21.250621
# 7                     0.010                    10.00  21.188611
# 8                     0.100                     0.01  22.180678
# 9                     0.100                     0.10  22.411526
# 10                    0.100                     1.00  22.245110
# 11                    0.100                    10.00  21.938910
# 12                    0.500                     0.01  29.707501
# 13                    0.500                     0.10  22.543207
# 14                    0.500                     1.00  21.554741
# 15                    0.500                    10.00  21.413221

# %%
best_params = all_params[np.argmin(rmses)]
print(best_params)
# Out:
# {'changepoint_prior_scale': 0.001, 'seasonality_prior_scale': 10.0}

# %%
# model = Prophet(changepoint_prior_scale=0.5,
#                     seasonality_prior_scale=2,
#                     seasonality_mode='multiplicative',
#                     changepoint_range=0.8,
#                     #holidays_prior_scale= 1,
#                     #seasonality_mode='additive',
#                     #growth='logistic', 
#                     yearly_seasonality= 10
#                     )

# %%
model_tuned = Prophet(changepoint_prior_scale=0.001,
                      seasonality_prior_scale=10,
                     )

# %%
model_tuned.fit(df)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/wca6dzpu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/3r4ejfkk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=80688', 'data', 'file=/tmp/tmp7pouhm3t/wca6dzpu.json', 'init=/tmp/tmp7pouhm3t/3r4ejfkk.json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_model81egaywh/prophet_model-20221212201300.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:13:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:13:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 20:13:00 - cmdstanpy - ERROR - Chain [1] error: error during processing Communication error on send
# ERROR:cmdstanpy:Chain [1] error: error during processing Communication error on send
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/hakw9_tn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/zxq4jmol.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=21575', 'data', 'file=/tmp/tmp7pouhm3t/hakw9_tn.json', 'init=/tmp/tmp7pouhm3t/zxq4jmol.json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_
.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:13:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:13:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 20:13:22 - cmdstanpy - ERROR - Chain [1] error: error during processing Communication error on send
# ERROR:cmdstanpy:Chain [1] error: error during processing Communication error on send
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/ew705_s2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/4cct3ccj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85684', 'data', 'file=/tmp/tmp7pouhm3t/ew705_s2.json', 'init=/tmp/tmp7pouhm3t/4cct3ccj.json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_modelv__1snyk/prophet_model-20221212201322.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 20:13:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:13:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/crcfytfo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/jzufw6vy.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=5787', 'data', 'file=/tmp/tmp7pouhm3t/crcfytfo.json', 'init=/tmp/tmp7pouhm3t/jzufw6vy.json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_modelnx19i66m/prophet_model-20221212201323.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:13:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:13:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 20:13:23 - cmdstanpy - ERROR - Chain [1] error: error during processing Communication error on send
# ERROR:cmdstanpy:Chain [1] error: error during processing Communication error on send
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/w61zgcc4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7pouhm3t/iwn_qni7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=55521', 'data', 'file=/tmp/tmp7pouhm3t/w61zgcc4.json', 'init=/tmp/tmp7pouhm3t/iwn_qni7.json', 'output', 'file=/tmp/tmp7pouhm3t/prophet_model_l9iti71/prophet_model-20221212201323.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 20:13:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:13:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
df_performance=performance_metrics(df_cv_final)
df_performance
# Out:
#      horizon         mse       rmse        mae      mape     mdape     smape  \
# 0    38 days  339.858851  18.435261  14.990286  0.019352  0.018142  0.019334
# 1    41 days  340.348997  18.448550  15.075368  0.019470  0.018142  0.019453
# 2    42 days  374.525817  19.352669  16.135571  0.020858  0.019702  0.020872
# 3    43 days  365.135800  19.108527  15.869821  0.020449  0.019344  0.020453
# 4    46 days  392.041377  19.800035  16.367299  0.020935  0.019344  0.020957
# ..       ...         ...        ...        ...       ...       ...       ...
# 180 357 days  495.384744  22.257240  19.327597  0.023534  0.020399  0.023361
# 181 360 days  505.811602  22.490256  19.944334  0.024245  0.023204  0.024066
# 182 361 days  491.085530  22.160450  19.346548  0.023617  0.020399  0.023447
# 183 362 days  573.598474  23.949916  20.625090  0.024974  0.023204  0.024758
# 184 365 days  532.871314  23.084006  20.011383  0.024075  0.023204  0.023894
#
#      coverage
# 0        0.44
# 1        0.44
# 2        0.40
# 3        0.40
# 4        0.44
# ..        ...
# 180      0.24
# 181      0.20
# 182      0.24
# 183      0.24
# 184      0.24
#
# [185 rows x 8 columns]

# %%
fig=plot_cross_validation_metric(df_cv_final,metric='rmse')
# Out:
# /usr/local/lib/python3.8/dist-packages/prophet/plot.py:544: FutureWarning: casting timedelta64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.
#   x_plt = df_none['horizon'].astype('timedelta64[ns]').astype(np.int64) / float(dt_conversions[i])
# /usr/local/lib/python3.8/dist-packages/prophet/plot.py:545: FutureWarning: casting timedelta64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.
#   x_plt_h = df_h['horizon'].astype('timedelta64[ns]').astype(np.int64) / float(dt_conversions[i])

# %%
fig=plot_cross_validation_metric(df_cv_final,metric='mape')
# Out:
# /usr/local/lib/python3.8/dist-packages/prophet/plot.py:544: FutureWarning: casting timedelta64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.
#   x_plt = df_none['horizon'].astype('timedelta64[ns]').astype(np.int64) / float(dt_conversions[i])
# /usr/local/lib/python3.8/dist-packages/prophet/plot.py:545: FutureWarning: casting timedelta64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.
#   x_plt_h = df_h['horizon'].astype('timedelta64[ns]').astype(np.int64) / float(dt_conversions[i])

# %%
plot1 = model_tuned.plot(forecast)

# %%
######################### Dynamic PLOT ###############################
from prophet.plot import plot_plotly
from datetime import datetime

fig = plot_plotly(model_tuned, forecast)
fig.update_layout( 
                  yaxis_title="Milk Production",
                  xaxis_title="Data",
                  title="Milk Production",
                  )
#################### vertical line ############
#fig.add_vline(x=datetime.today(), line_width=3, line_dash="dash", line_color="red")
##############################################
#st.plotly_chart(fig)

fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b9ecf0d0-816a-4260-a50a-846173eb512b" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9ecf0d0-816a-4260-a50a-846173eb512b")) {                    Plotly.newPlot(                        "b9ecf0d0-816a-4260-a50a-846173eb512b",                        [{"marker":{"color":"black","size":4},"mode":"markers","name":"Actual","x":["1962-01-01T00:00:00","1962-02-01T00:00:00","1962-03-01T00:00:00","1962-04-01T00:00:00","1962-05-01T00:00:00","1962-06-01T00:00:00","1962-07-01T00:00:00","1962-08-01T00:00:00","1962-09-01T00:00:00","1962-10-01T00:00:00","1962-11-01T00:00:00","1962-12-01T00:00:00","1963-01-01T00:00:00","1963-02-01T00:00:00","1963-03-01T00:00:00","1963-04-01T00:00:00","1963-05-01T00:00:00","1963-06-01T00:00:00","1963-07-01T00:00:00","1963-08-01T00:00:00","1963-09-01T00:00:00","1963-10-01T00:00:00","1963-11-01T00:00:00","1963-12-01T00:00:00","1964-01-01T00:00:00","1964-02-01T00:00:00","1964-03-01T00:00:00","1964-04-01T00:00:00","1964-05-01T00:00:00","1964-06-01T00:00:00","1964-07-01T00:00:00","1964-08-01T00:00:00","1964-09-01T00:00:00","1964-10-01T00:00:00","1964-11-01T00:00:00","1964-12-01T00:00:00","1965-01-01T00:00:00","1965-02-01T00:00:00","1965-03-01T00:00:00","1965-04-01T00:00:00","1965-05-01T00:00:00","1965-06-01T00:00:00","1965-07-01T00:00:00","1965-08-01T00:00:00","1965-09-01T00:00:00","1965-10-01T00:00:00","1965-11-01T00:00:00","1965-12-01T00:00:00","1966-01-01T00:00:00","1966-02-01T00:00:00","1966-03-01T00:00:00","1966-04-01T00:00:00","1966-05-01T00:00:00","1966-06-01T00:00:00","1966-07-01T00:00:00","1966-08-01T00:00:00","1966-09-01T00:00:00","1966-10-01T00:00:00","1966-11-01T00:00:00","1966-12-01T00:00:00","1967-01-01T00:00:00","1967-02-01T00:00:00","1967-03-01T00:00:00","1967-04-01T00:00:00","1967-05-01T00:00:00","1967-06-01T00:00:00","1967-07-01T00:00:00","1967-08-01T00:00:00","1967-09-01T00:00:00","1967-10-01T00:00:00","1967-11-01T00:00:00","1967-12-01T00:00:00","1968-01-01T00:00:00","1968-02-01T00:00:00","1968-03-01T00:00:00","1968-04-01T00:00:00","1968-05-01T00:00:00","1968-06-01T00:00:00","1968-07-01T00:00:00","1968-08-01T00:00:00","1968-09-01T00:00:00","1968-10-01T00:00:00","1968-11-01T00:00:00","1968-12-01T00:00:00","1969-01-01T00:00:00","1969-02-01T00:00:00","1969-03-01T00:00:00","1969-04-01T00:00:00","1969-05-01T00:00:00","1969-06-01T00:00:00","1969-07-01T00:00:00","1969-08-01T00:00:00","1969-09-01T00:00:00","1969-10-01T00:00:00","1969-11-01T00:00:00","1969-12-01T00:00:00","1970-01-01T00:00:00","1970-02-01T00:00:00","1970-03-01T00:00:00","1970-04-01T00:00:00","1970-05-01T00:00:00","1970-06-01T00:00:00","1970-07-01T00:00:00","1970-08-01T00:00:00","1970-09-01T00:00:00","1970-10-01T00:00:00","1970-11-01T00:00:00","1970-12-01T00:00:00","1971-01-01T00:00:00","1971-02-01T00:00:00","1971-03-01T00:00:00","1971-04-01T00:00:00","1971-05-01T00:00:00","1971-06-01T00:00:00","1971-07-01T00:00:00","1971-08-01T00:00:00","1971-09-01T00:00:00","1971-10-01T00:00:00","1971-11-01T00:00:00","1971-12-01T00:00:00","1972-01-01T00:00:00","1972-02-01T00:00:00","1972-03-01T00:00:00","1972-04-01T00:00:00","1972-05-01T00:00:00","1972-06-01T00:00:00","1972-07-01T00:00:00","1972-08-01T00:00:00","1972-09-01T00:00:00","1972-10-01T00:00:00","1972-11-01T00:00:00","1972-12-01T00:00:00","1973-01-01T00:00:00","1973-02-01T00:00:00","1973-03-01T00:00:00","1973-04-01T00:00:00","1973-05-01T00:00:00","1973-06-01T00:00:00","1973-07-01T00:00:00","1973-08-01T00:00:00","1973-09-01T00:00:00","1973-10-01T00:00:00","1973-11-01T00:00:00","1973-12-01T00:00:00","1974-01-01T00:00:00","1974-02-01T00:00:00","1974-03-01T00:00:00","1974-04-01T00:00:00","1974-05-01T00:00:00","1974-06-01T00:00:00","1974-07-01T00:00:00","1974-08-01T00:00:00","1974-09-01T00:00:00","1974-10-01 ...

# %% [markdown]
# ### The Prophet model has a number of input parameters that one might consider tuning. Here are some general recommendations for hyperparameter tuning that may be a good starting place.
#
# Parameters that can be tuned
#
# changepoint_prior_scale: This is probably the most impactful parameter. It determines the flexibility of the trend, and in particular how much the trend changes at the trend changepoints. As described in this documentation, if it is too small, the trend will be underfit and variance that should have been modeled with trend changes will instead end up being handled with the noise term. If it is too large, the trend will overfit and in the most extreme case you can end up with the trend capturing yearly seasonality. The default of 0.05 works for many time series, but this could be tuned; a range of [0.001, 0.5] would likely be about right. Parameters like this (regularization penalties; this is effectively a lasso penalty) are often tuned on a log scale.
#
# seasonality_prior_scale: This parameter controls the flexibility of the seasonality. Similarly, a large value allows the seasonality to fit large fluctuations, a small value shrinks the magnitude of the seasonality. The default is 10., which applies basically no regularization. That is because we very rarely see overfitting here (there’s inherent regularization with the fact that it is being modeled with a truncated Fourier series, so it’s essentially low-pass filtered). A reasonable range for tuning it would probably be [0.01, 10]; when set to 0.01 you should find that the magnitude of seasonality is forced to be very small. This likely also makes sense on a log scale, since it is effectively an L2 penalty like in ridge regression.
#
# holidays_prior_scale: This controls flexibility to fit holiday effects. Similar to seasonality_prior_scale, it defaults to 10.0 which applies basically no regularization, since we usually have multiple observations of holidays and can do a good job of estimating their effects. This could also be tuned on a range of [0.01, 10] as with seasonality_prior_scale.
#
# seasonality_mode: Options are ['additive', 'multiplicative']. Default is 'additive', but many business time series will have multiplicative seasonality. This is best identified just from looking at the time series and seeing if the magnitude of seasonal fluctuations grows with the magnitude of the time series (see the documentation here on multiplicative seasonality), but when that isn’t possible, it could be tuned.
#
# Maybe tune?
#
# changepoint_range: This is the proportion of the history in which the trend is allowed to change. This defaults to 0.8, 80% of the history, meaning the model will not fit any trend changes in the last 20% of the time series. This is fairly conservative, to avoid overfitting to trend changes at the very end of the time series where there isn’t enough runway left to fit it well. With a human in the loop, this is something that can be identified pretty easily visually: one can pretty clearly see if the forecast is doing a bad job in the last 20%. In a fully-automated setting, it may be beneficial to be less conservative. It likely will not be possible to tune this parameter effectively with cross validation over cutoffs as described above. The ability of the model to generalize from a trend change in the last 10% of the time series will be hard to learn from looking at earlier cutoffs that may not have trend changes in the last 10%. So, this parameter is probably better not tuned, except perhaps over a large number of time series. In that setting, [0.8, 0.95] may be a reasonable range.
# Parameters that would likely not be tuned
#
# growth: Options are ‘linear’ and ‘logistic’. This likely will not be tuned; if there is a known saturating point and growth towards that point it will be included and the logistic trend will be used, otherwise it will be linear.
#
# changepoints: This is for manually specifying the locations of changepoints. None by default, which automatically places them.
#
# n_changepoints: This is the number of automatically placed changepoints. The default of 25 should be plenty to capture the trend changes in a typical time series (at least the type that Prophet would work well on anyway). Rather than increasing or decreasing the number of changepoints, it will likely be more effective to focus on increasing or decreasing the flexibility at those trend changes, which is done with changepoint_prior_scale.
#
# yearly_seasonality: By default (‘auto’) this will turn yearly seasonality on if there is a year of data, and off otherwise. Options are [‘auto’, True, False]. If there is more than a year of data, rather than trying to turn this off during HPO, it will likely be more effective to leave it on and turn down seasonal effects by tuning seasonality_prior_scale.
#
# weekly_seasonality: Same as for yearly_seasonality.
#
# daily_seasonality: Same as for yearly_seasonality.
#
# holidays: This is to pass in a dataframe of specified holidays. The holiday effects would be tuned with holidays_prior_scale.
#
# mcmc_samples: Whether or not MCMC is used will likely be determined by factors like the length of the time series and the importance of parameter uncertainty (these considerations are described in the documentation).
#
# interval_width: Prophet predict returns uncertainty intervals for each component, like yhat_lower and yhat_upper for the forecast yhat. These are computed as quantiles of the posterior predictive distribution, and interval_width specifies which quantiles to use. The default of 0.8 provides an 80% prediction interval. You could change that to 0.95 if you wanted a 95% interval. This will affect only the uncertainty interval, and will not change the forecast yhat at all and so does not need to be tuned.
#
# uncertainty_samples: The uncertainty intervals are computed as quantiles from the posterior predictive interval, and the posterior predictive interval is estimated with Monte Carlo sampling. This parameter is the number of samples to use (defaults to 1000). The running time for predict will be linear in this number. Making it smaller will increase the variance (Monte Carlo error) of the uncertainty interval, and making it larger will reduce that variance. So, if the uncertainty estimates seem jagged this could be increased to further smooth them out, but it likely will not need to be changed. As with interval_width, this parameter only affects the uncertainty intervals and changing it will not affect in any way the forecast yhat; it does not need to be tuned.
#
# stan_backend: If both pystan and cmdstanpy backends set up, the backend can be specified. The predictions will be the same, this will not be tuned.
